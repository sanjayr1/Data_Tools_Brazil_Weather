# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
#df = pd.read_csv('/Users/coady/Data_Tools_Brazil_Weather/sudeste.csv')

# %%
#df.to_hdf('weather.hdf','mydata',mode='w')

# %%
df = pd.read_hdf('weather.hdf','mydata')

# %%
df = df.set_index('mdct')
df.index = pd.to_datetime(df.index)

# %%
df.shape
# Out:
# (9779168, 30)

# %%
df.isna().sum()
# Out:
# wsid          0
# wsnm          0
# elvt          0
# lat           0
# lon           0
# inme          0
# city          0
# prov          0
# date          0
# yr            0
# mo            0
# da            0
# hr            0
# prcp    8371184
# stp           0
# smax          0
# smin          0
# gbrd    4108820
# temp         31
# dewp        475
# tmax         26
# dmax        310
# tmin         34
# dmin        807
# hmdy          0
# hmax         12
# hmin         44
# wdsp     925561
# wdct          0
# gust     316474
# dtype: int64

# %%
(df == 0).sum(axis=0)
# Out:
# wsid         0
# wsnm         0
# elvt     71760
# lat      71760
# lon      71760
# inme         0
# city         0
# prov         0
# date         0
# yr           0
# mo           0
# da           0
# hr      407466
# prcp    746679
# stp     701723
# smax    705438
# smin    705358
# gbrd    879490
# temp    628611
# dewp    705849
# tmax    631473
# dmax    706613
# tmin    631410
# dmin    714946
# hmdy    679673
# hmax    677458
# hmin    684793
# wdsp    828184
# wdct    870382
# gust    841180
# dtype: int64

# %%
df[["wsid", "city", "prov", "elvt", "lat", "lon"]].drop_duplicates()
# Out:
#             wsid                      city prov    elvt        lat        lon
# mdct
# 2007-11-06   178               São Gonçalo   RJ   237.0  -6.835777 -38.311583
# 2006-10-31   303                   Vitória   ES     9.0 -20.271094 -40.306069
# 2007-08-09   304              Santa Teresa   ES   976.0 -19.988388 -40.579572
# 2006-10-27   305                  Linhares   ES    38.0 -19.356923 -40.068680
# 2006-11-03   306            Alfredo Chaves   ES    14.0 -20.636526 -40.741818
# 2006-10-25   307                São Mateus   ES    29.0 -18.676198 -39.864051
# 2006-10-25   308                    Alegre   ES   129.0 -20.750412 -41.488852
# 2008-06-18   309        Presidente Kennedy   ES    69.0 -21.100805 -41.039395
# 2008-06-22   310              Nova Venécia   ES   156.0 -18.695265 -40.390572
# 2011-09-24   311            Afonso Cláudio   ES   507.0 -20.104194 -41.106861
# 2002-12-05   312                 Barbacena   MG  1169.0 -21.228373 -43.767703
# 2002-12-19   313                     Araxá   MG  1018.0 -19.605696 -46.949617
# 2002-12-19   314             Montes Claros   MG   646.0 -16.686316 -43.843763
# 2002-12-18   315                Uberlândia   MG   875.0 -18.917072 -48.255657
# 2002-12-15   316                  Almenara   MG   189.0 -16.166773 -40.687756
# 2004-12-19   317               Camanducaia   MG  1545.0 -22.861604 -46.043365
# 2005-09-15   318                    Viçosa   MG   698.0 -20.762607 -42.864013
# 2006-02-22   319                   Timóteo   MG   493.0 -19.573824 -42.622413
# 2006-05-12   320                 Ituiutaba   MG   540.0 -18.952907 -49.525072
# 2006-07-28   321               Ouro Branco   MG  1048.0 -20.556592 -43.756220
# 2006-06-09   322          São João del Rei   MG   930.0 -21.106502 -44.250928
# 2006-09-01   403                 Rancharia   SP   399.0 -22.372832 -50.974710
# 2006-09-22   404                     Avaré   SP   776.0 -23.101749 -48.940997
# 2006-09-26   405                Piracicaba   SP   566.0 -22.703132 -47.623317
# 2006-09-20   406                      Lins   SP   461.0 -21.666045 -49.734854
# 2006-12-20   407                   Taubaté   SP   582.0 -23.041668 -45.520841
# 2006-12-04   408               Votuporanga   SP   510.0 -20.403221 -49.966031
# 2007-08-22   409                     Jales   SP   460.0 -20.165025 -50.595134
# 2007-08-30   410                Valparaíso   SP   382.0 -21.319138 -50.930158
# 2007-09-03   411            José Bonifácio   SP   408.0 -21.085675 -49.920388
# 2007-11-13   412                  Ariranha   SP   525.0 -21.132937 -48.840426
# 2007-11-09   413                  Ibitinga   SP   497.0 -21.855567 -48.799717
# 2007-06-28   414               Casa Branca   SP   734.0 -21.780560 -47.075280
# 2007-11-07   415                   Itapira   SP   635.0 -22.415062 -46.805292
# 2007-11-01   416    São Luís do Paraitinga   SP   862.0 -23.228362 -45.417055
# 2008-04-24   417              Barra Bonita   SP   534.0 -22.471205 -48.557573
# 2008-07-25   418                   Guarujá   SP     0.0   0.000000   0.000000
# 2008-07-03   419            Barra do Turvo   SP   660.0 -24.962819 -48.416379
# 2008-04-22   420                Pradópolis   SP   540.0 -21.338432 -48.114007
# 2010-06-19   421                  Barretos   SP   534.0 -20.559175 -48.544997
# 2008-07-17   422                 Ituverava   SP   611.0 -20.359760 -47.775220
# 2011-03-29   423                   Barueri   SP   777.0 -23.523890 -46.869450

# %%
df[df.elvt == 0].wsid.unique()
# Out:
# array([418])

# %% [markdown]
# This explains the 0 values. Maybe the metadata for the station did not get input correctly? Let's go to the internet and see what the average lat/lon and elevation is for Guarujá
#
# https://en.wikipedia.org/wiki/Guaruj%C3%A1
#
# It is a very small area (55 sq miles) Elevation is 4 meters lat lon is 23°59′37″S 46°15′23″W --> lat -23.993611, lon -46.256389 We can change this in our dataset to get a more accurate description

# %%
df['elvt'].replace(0, 4, inplace=True)
df['lat'].replace(0, -23.993611, inplace=True)
df['lon'].replace(0, -46.256389, inplace=True)

# %%
(df == 0).sum(axis=0)
# Out:
# wsid         0
# wsnm         0
# elvt         0
# lat          0
# lon          0
# inme         0
# city         0
# prov         0
# date         0
# yr           0
# mo           0
# da           0
# hr      407466
# prcp    746679
# stp     701723
# smax    705438
# smin    705358
# gbrd    879490
# temp    628611
# dewp    705849
# tmax    631473
# dmax    706613
# tmin    631410
# dmin    714946
# hmdy    679673
# hmax    677458
# hmin    684793
# wdsp    828184
# wdct    870382
# gust    841180
# dtype: int64

# %%
# !pip install folium
# Out:
# Collecting folium
#   Downloading https://files.pythonhosted.org/packages/47/28/b3199bf87100e389c1dff88a44a38936d27e5e99eece870b5308186217c8/folium-0.8.2-py2.py3-none-any.whl (87kB)
#     100% |████████████████████████████████| 92kB 4.0MB/s ta 0:00:01
# Collecting branca>=0.3.0 (from folium)
#   Downloading https://files.pythonhosted.org/packages/63/36/1c93318e9653f4e414a2e0c3b98fc898b4970e939afeedeee6075dd3b703/branca-0.3.1-py3-none-any.whl
# Requirement already satisfied: requests in /Applications/anaconda3/lib/python3.6/site-packages (from folium) (2.18.4)
# Requirement already satisfied: jinja2 in /Applications/anaconda3/lib/python3.6/site-packages (from folium) (2.10)
# Requirement already satisfied: six in /Applications/anaconda3/lib/python3.6/site-packages (from folium) (1.11.0)
# Requirement already satisfied: numpy in /Applications/anaconda3/lib/python3.6/site-packages (from folium) (1.14.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Applications/anaconda3/lib/python3.6/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /Applications/anaconda3/lib/python3.6/site-packages (from requests->folium) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /Applications/anaconda3/lib/python3.6/site-packages (from requests->folium) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /Applications/anaconda3/lib/python3.6/site-packages (from requests->folium) (2018.1.18)
# Requirement already satisfied: MarkupSafe>=0.23 in /Applications/anaconda3/lib/python3.6/site-packages (from jinja2->folium) (1.0)
# Installing collected packages: branca, folium
# Successfully installed branca-0.3.1 folium-0.8.2

# %%
import seaborn
import folium

# %%
map = df[["wdsp", "wdct"]].drop_duplicates()
